# %%
import os
import pandas as pd

folder_path = '../data/Stocks/'
all_columns = set()

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path, nrows=0)  # Read only headers
        all_columns.update(df.columns)

print("Unique column names found:", all_columns)
# Out:
# Unique column names found: {'Low', 'High', 'Open', 'Volume', 'Date', 'Close', 'Turnover', 'Symbol'}

# %%
import os
import pandas as pd

folder_path = '../data/Stocks/'
cols_to_remove = ['Percent Change', '% Change']  # Add any variant

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Convert column names to string and check for matches
        cols_to_drop = [col for col in df.columns if col in cols_to_remove]
        
        if cols_to_drop:
            df = df.drop(columns=cols_to_drop)
        
        # Convert 'Date' to datetime and sort
        df['Date'] = pd.to_datetime(df['Date'])
        df = df.sort_values('Date').reset_index(drop=True)
        
        # Save back
        df.to_csv(file_path, index=False)
        print(f"Processed: {filename}, removed columns: {cols_to_drop}")
# Out:
# Processed: ICFCD83.csv, removed columns: ['Percent Change']
# Processed: LBBLD89.csv, removed columns: ['Percent Change']
# Processed: SPL.csv, removed columns: ['Percent Change']
# Processed: BARUN.csv, removed columns: ['Percent Change']
# Processed: NYADI.csv, removed columns: ['Percent Change']
# Processed: SAGF.csv, removed columns: ['Percent Change']
# Processed: SANVI.csv, removed columns: ['Percent Change']
# Processed: PSF.csv, removed columns: ['Percent Change']
# Processed: NIMBPO.csv, removed columns: ['Percent Change']
# Processed: USHL.csv, removed columns: ['Percent Change']
# Processed: SMFBS.csv, removed columns: ['Percent Change']
# Processed: MIDBL.csv, removed columns: ['% Change']
# Processed: MBLEF.csv, removed columns: ['Percent Change']
# Processed: GIBF1.csv, removed columns: ['Percent Change']
# Processed: KDBL.csv, removed columns: ['% Change']
# Processed: BEDC.csv, removed columns: ['Percent Change']
# Processed: CDBL.csv, removed columns: ['% Change']
# Processed: SFCL.csv, removed columns: ['Percent Change']
# Processed: NSLB.csv, removed columns: ['Percent Change']
# Processed: GVL.csv, removed columns: ['Percent Change']
# Processed: NBBL.csv, removed columns: ['Percent Change']
# Processed: NCCB.csv, removed columns: ['Percent Change']
# Processed: CHL.csv, removed columns: ['Percent Change']
# Processed: UAIL.csv, removed columns: ['Percent Change']
# Processed: GBIME.csv, removed columns: ['Percent Change']
# Processed: SALICO.csv, removed columns: ['Percent Change']
# Processed: RHPC.csv, removed columns: ['% Change']
# Processed: NICSF.csv, removed columns: ['Percent Change']
# Processed: GBBL.csv, removed columns: ['Percent Change']
# Processed: MMFDB.csv, removed columns: ['Percent Change']
# Processed: LICN.csv, removed columns: ['Percent Change']
# Processed: NMBHF2.csv, removed columns: ['Percent Change']
# Processed: PPCL.csv, removed columns: ['Percent Change']
# Processed: SJCL.csv, removed columns: ['Percent Change']
# Processed: NIMB.csv, removed columns: ['Percent Change']
# Processed: KSLY.csv, removed columns: ['Percent Change']
# Processed: SMHL.csv, removed columns: ['Percent Change']
# Processed: NMLBBL.csv, removed columns: ['Percent Change']
# Processed: ULBSL.csv, removed columns: ['Percent Change']
# Processed: NICA.csv, removed columns: ['Percent Change']
# Processed: KBLPO.csv, removed columns: ['Percent Change']
# Processed: PFL.csv, removed columns: ['Percent Change']
# Processed: ALICL.csv, removed columns: ['Percent Change']
# Processed: NICGF.csv, removed columns: ['Percent Change']
# Processed: GABL.csv, removed columns: ['% Change']
# Processed: HATHY.csv, removed columns: ['Percent Change']
# Processed: NIDC.csv, removed columns: ['% Change']
# Processed: RAWA.csv, removed columns: ['Percent Change']
# Processed: PCBL.csv, removed columns: ['Percent Change']
# Processed: HRL.csv, removed columns: ['Percent Change']
# Processed: NABBC.csv, removed columns: ['Percent Change']
# Processed: H8020.csv, removed columns: ['Percent Change']
# Processed: MATRI.csv, removed columns: ['Percent Change']
# Processed: ULI.csv, removed columns: ['Percent Change']
# Processed: MSLB.csv, removed columns: ['Percent Change']
# Processed: ARDBL.csv, removed columns: ['% Change']
# Processed: ULHC.csv, removed columns: ['Percent Change']
# Processed: NIBLPF.csv, removed columns: ['Percent Change']
# Processed: MKJC.csv, removed columns: ['Percent Change']
# Processed: SMATA.csv, removed columns: ['Percent Change']
# Processed: NICGF2.csv, removed columns: ['Percent Change']
# Processed: SBID2090.csv, removed columns: ['Percent Change']
# Processed: SPARS.csv, removed columns: ['Percent Change']
# Processed: JBBL.csv, removed columns: ['Percent Change']
# Processed: RFPL.csv, removed columns: ['Percent Change']
# Processed: NMFBS.csv, removed columns: ['Percent Change']
# Processed: NIBLSF.csv, removed columns: ['Percent Change']
# Processed: AHPC.csv, removed columns: ['Percent Change']
# Processed: CKHL.csv, removed columns: ['Percent Change']
# Processed: CEFL.csv, removed columns: ['Percent Change']
# Processed: NADEP.csv, removed columns: ['Percent Change']
# Processed: NIBLSTF.csv, removed columns: ['Percent Change']
# Processed: ICFCD88.csv, removed columns: ['Percent Change']
# Processed: SMH.csv, removed columns: ['Percent Change']
# Processed: SLICL.csv, removed columns: ['Percent Change']
# Processed: OMPL.csv, removed columns: ['Percent Change']
# Processed: RHGCL.csv, removed columns: ['Percent Change']
# Processed: SINDU.csv, removed columns: ['Percent Change']
# Processed: KSBBL.csv, removed columns: ['Percent Change']
# Processed: SIC.csv, removed columns: ['Percent Change']
# Processed: GUFL.csv, removed columns: ['Percent Change']
# Processed: GBBD85.csv, removed columns: ['Percent Change']
# Processed: BJHL.csv, removed columns: ['Percent Change']
# Processed: UFIL.csv, removed columns: ['% Change']
# Processed: NBF3.csv, removed columns: ['Percent Change']
# Processed: FOWAD.csv, removed columns: ['Percent Change']
# Processed: MLBL.csv, removed columns: ['Percent Change']
# Processed: NBSL.csv, removed columns: ['% Change']
# Processed: JFL.csv, removed columns: ['Percent Change']
# Processed: LBL.csv, removed columns: ['Percent Change']
# Processed: BHL.csv, removed columns: ['Percent Change']
# Processed: DBBL.csv, removed columns: ['Percent Change']
# Processed: LBLD86.csv, removed columns: ['Percent Change']
# Processed: DORDI.csv, removed columns: ['Percent Change']
# Processed: HBL.csv, removed columns: ['Percent Change']
# Processed: CLI.csv, removed columns: ['Percent Change']
# Processed: SIGS3.csv, removed columns: ['Percent Change']
# Processed: SHLB.csv, removed columns: ['Percent Change']
# Processed: SHPC.csv, removed columns: ['Percent Change']
# Processed: KRBL.csv, removed columns: ['Percent Change']
# Processed: SPC.csv, removed columns: ['Percent Change']
# Processed: WOMI.csv, removed columns: ['% Change']
# Processed: SOHL.csv, removed columns: ['Percent Change']
# Processed: TPC.csv, removed columns: ['Percent Change']
# Processed: SETI.csv, removed columns: ['% Change']
# Processed: PRSF.csv, removed columns: ['Percent Change']
# Processed: HLBSL.csv, removed columns: ['Percent Change']
# Processed: NBF2.csv, removed columns: ['Percent Change']
# Processed: NABILP.csv, removed columns: ['Percent Change']
# Processed: UPCL.csv, removed columns: ['Percent Change']
# Processed: RBCLPO.csv, removed columns: ['Percent Change']
# Processed: NLG.csv, removed columns: ['Percent Change']
# Processed: ODBL.csv, removed columns: ['Percent Change']
# Processed: SAGAR.csv, removed columns: ['Percent Change']
# Processed: USLB.csv, removed columns: ['Percent Change']
# Processed: GRDBL.csv, removed columns: ['Percent Change']
# Processed: JBLB.csv, removed columns: ['Percent Change']
# Processed: KBSH.csv, removed columns: ['Percent Change']
# Processed: KDL.csv, removed columns: ['Percent Change']
# Processed: KSY.csv, removed columns: ['Percent Change']
# Processed: LGIL.csv, removed columns: ['Percent Change']
# Processed: PHCL.csv, removed columns: ['Percent Change']
# Processed: MMF1.csv, removed columns: ['Percent Change']
# Processed: RLFL.csv, removed columns: ['Percent Change']
# Processed: NICBF.csv, removed columns: ['Percent Change']
# Processed: NIFRA.csv, removed columns: ['Percent Change']
# Processed: NCDB.csv, removed columns: ['Percent Change']
# Processed: JHBL.csv, removed columns: ['% Change']
# Processed: NRIC.csv, removed columns: ['Percent Change']
# Processed: C30MF.csv, removed columns: ['Percent Change']
# Processed: MANDU.csv, removed columns: ['Percent Change']
# Processed: SIL.csv, removed columns: ['Percent Change']
# Processed: SGHC.csv, removed columns: ['Percent Change']
# Processed: ADLB.csv, removed columns: ['Percent Change']
# Processed: LSL.csv, removed columns: ['Percent Change']
# Processed: API.csv, removed columns: ['Percent Change']
# Processed: KMCDB.csv, removed columns: ['Percent Change']
# Processed: BSBL.csv, removed columns: ['% Change']
# Processed: RLI.csv, removed columns: ['Percent Change']
# Processed: NRM.csv, removed columns: ['Percent Change']
# Processed: UNLB.csv, removed columns: ['Percent Change']
# Processed: GCIL.csv, removed columns: ['Percent Change']
# Processed: NGBL.csv, removed columns: ['% Change']
# Processed: KSBBLD87.csv, removed columns: ['% Change']
# Processed: NBBU.csv, removed columns: ['Percent Change']
# Processed: MFIL.csv, removed columns: ['Percent Change']
# Processed: ICFC.csv, removed columns: ['Percent Change']
# Processed: SFFIL.csv, removed columns: ['Percent Change']
# Processed: SBID89.csv, removed columns: ['Percent Change']
# Processed: CGH.csv, removed columns: ['Percent Change']
# Processed: RNLI.csv, removed columns: ['Percent Change']
# Processed: SLK.csv, removed columns: ['Percent Change']
# Processed: RMDC.csv, removed columns: ['Percent Change']
# Processed: BFC.csv, removed columns: ['Percent Change']
# Processed: STC.csv, removed columns: ['Percent Change']
# Processed: KBL.csv, removed columns: ['Percent Change']
# Processed: SHINE.csv, removed columns: ['Percent Change']
# Processed: GBLBS.csv, removed columns: ['Percent Change']
# Processed: HIDCL.csv, removed columns: ['Percent Change']
# Processed: SKHEL.csv, removed columns: ['Percent Change']
# Processed: SIFC.csv, removed columns: ['Percent Change']
# Processed: PICL.csv, removed columns: ['Percent Change']
# Processed: SHIVM.csv, removed columns: ['Percent Change']
# Processed: SADBL.csv, removed columns: ['Percent Change']
# Processed: SEOS.csv, removed columns: ['Percent Change']
# Processed: NICLBSL.csv, removed columns: ['Percent Change']
# Processed: RIDI.csv, removed columns: ['Percent Change']
# Processed: LEC.csv, removed columns: ['Percent Change']
# Processed: MEGA.csv, removed columns: ['Percent Change']
# Processed: GMFBS.csv, removed columns: ['Percent Change']
# Processed: CREST.csv, removed columns: ['Percent Change']
# Processed: NEPSE.csv, removed columns: ['Percent Change']
# Processed: MKHC.csv, removed columns: ['Percent Change']
# Processed: LVF1.csv, removed columns: ['Percent Change']
# Processed: IGI.csv, removed columns: ['Percent Change']
# Processed: NHPC.csv, removed columns: ['Percent Change']
# Processed: UIC.csv, removed columns: ['Percent Change']
# Processed: SRBL.csv, removed columns: ['Percent Change']
# Processed: TBBL.csv, removed columns: ['% Change']
# Processed: NLIC.csv, removed columns: ['Percent Change']
# Processed: VLUCL.csv, removed columns: ['Percent Change']
# Processed: TRH.csv, removed columns: ['Percent Change']
# Processed: SCB.csv, removed columns: ['Percent Change']
# Processed: ANLB.csv, removed columns: ['Percent Change']
# Processed: HFIN.csv, removed columns: ['Percent Change']
# Processed: PLIC.csv, removed columns: ['Percent Change']
# Processed: CCBL.csv, removed columns: ['Percent Change']
# Processed: SBLD84.csv, removed columns: ['Percent Change']
# Processed: MHNL.csv, removed columns: ['Percent Change']
# Processed: SMB.csv, removed columns: ['Percent Change']
# Processed: UNHPL.csv, removed columns: ['Percent Change']
# Processed: NLBBL.csv, removed columns: ['Percent Change']
# Processed: SLBS.csv, removed columns: ['Percent Change']
# Processed: NMBMF.csv, removed columns: ['Percent Change']
# Processed: ALDBL.csv, removed columns: ['% Change']
# Processed: TMDBL.csv, removed columns: ['Percent Change']
# Processed: CIT.csv, removed columns: ['Percent Change']
# Processed: SRLI.csv, removed columns: ['Percent Change']
# Processed: HATH.csv, removed columns: ['% Change']
# Processed: HEIP.csv, removed columns: ['Percent Change']
# Processed: TAMOR.csv, removed columns: ['Percent Change']
# Processed: SHINED.csv, removed columns: ['Percent Change']
# Processed: PIC.csv, removed columns: ['Percent Change']
# Processed: NEF.csv, removed columns: ['Percent Change']
# Processed: KKBL.csv, removed columns: ['% Change']
# Processed: KBBL.csv, removed columns: ['% Change']
# Processed: CYCL.csv, removed columns: ['Percent Change']
# Processed: SLI.csv, removed columns: ['Percent Change']
# Processed: GBILD8485.csv, removed columns: ['Percent Change']
# Processed: BPCL.csv, removed columns: ['Percent Change']
# Processed: KLBSL.csv, removed columns: ['Percent Change']
# Processed: USHEC.csv, removed columns: ['Percent Change']
# Processed: PURBL.csv, removed columns: ['Percent Change']
# Processed: MNBBL.csv, removed columns: ['Percent Change']
# Processed: MHCL.csv, removed columns: ['Percent Change']
# Processed: MEL.csv, removed columns: ['Percent Change']
# Processed: RBS.csv, removed columns: ['Percent Change']
# Processed: ENL.csv, removed columns: ['Percent Change']
# Processed: KEF.csv, removed columns: ['Percent Change']
# Processed: NICFC.csv, removed columns: ['Percent Change']
# Processed: SHEL.csv, removed columns: ['Percent Change']
# Processed: SLBBL.csv, removed columns: ['Percent Change']
# Processed: BHCL.csv, removed columns: ['Percent Change']
# Processed: GSY.csv, removed columns: ['Percent Change']
# Processed: GWFD83.csv, removed columns: ['Percent Change']
# Processed: BHPL.csv, removed columns: ['Percent Change']
# Processed: KMBL.csv, removed columns: ['% Change']
# Processed: BBC.csv, removed columns: ['Percent Change']
# Processed: EHPL.csv, removed columns: ['Percent Change']
# Processed: RBCL.csv, removed columns: ['Percent Change']
# Processed: JOSHI.csv, removed columns: ['Percent Change']
# Processed: ACLBSL.csv, removed columns: ['Percent Change']
# Processed: PMHPL.csv, removed columns: ['Percent Change']
# Processed: SIKLES.csv, removed columns: ['Percent Change']
# Processed: SMFDB.csv, removed columns: ['Percent Change']
# Processed: NBB.csv, removed columns: ['Percent Change']
# Processed: NSIF2.csv, removed columns: ['Percent Change']
# Processed: MAKAR.csv, removed columns: ['Percent Change']
# Processed: MBL.csv, removed columns: ['Percent Change']
# Processed: BOKL.csv, removed columns: ['Percent Change']
# Processed: SPDL.csv, removed columns: ['Percent Change']
# Processed: FMDBL.csv, removed columns: ['Percent Change']
# Processed: BANDIPUR.csv, removed columns: ['Percent Change']
# Processed: HGI.csv, removed columns: ['Percent Change']
# Processed: HURJA.csv, removed columns: ['Percent Change']
# Processed: DHPL.csv, removed columns: ['Percent Change']
# Processed: NHDL.csv, removed columns: ['Percent Change']
# Processed: SHL.csv, removed columns: ['Percent Change']
# Processed: NMB50.csv, removed columns: ['Percent Change']
# Processed: CSY.csv, removed columns: ['Percent Change']
# Processed: JALPA.csv, removed columns: ['Percent Change']
# Processed: ILI.csv, removed columns: ['Percent Change']
# Processed: NMIC.csv, removed columns: ['Percent Change']
# Processed: PURE.csv, removed columns: ['Percent Change']
# Processed: SBBLJ.csv, removed columns: ['Percent Change']
# Processed: VLBS.csv, removed columns: ['Percent Change']
# Processed: SABBL.csv, removed columns: ['Percent Change']
# Processed: SWASTIK.csv, removed columns: ['Percent Change']
# Processed: BGWT.csv, removed columns: ['Percent Change']
# Processed: SYFL.csv, removed columns: ['Percent Change']
# Processed: SBCF.csv, removed columns: ['Percent Change']
# Processed: SFMF.csv, removed columns: ['Percent Change']
# Processed: AHL.csv, removed columns: ['Percent Change']
# Processed: RADHI.csv, removed columns: ['Percent Change']
# Processed: WDBL.csv, removed columns: ['% Change']
# Processed: NESDO.csv, removed columns: ['Percent Change']
# Processed: SBL.csv, removed columns: ['Percent Change']
# Processed: SSIS.csv, removed columns: ['Percent Change']
# Processed: HEI.csv, removed columns: ['Percent Change']
# Processed: MMDBL.csv, removed columns: ['% Change']
# Processed: UMHL.csv, removed columns: ['Percent Change']
# Processed: TDBL.csv, removed columns: ['% Change']
# Processed: SAIL.csv, removed columns: ['Percent Change']
# Processed: NLO.csv, removed columns: ['Percent Change']
# Processed: CZBIL.csv, removed columns: ['Percent Change']
# Processed: ADBL.csv, removed columns: ['Percent Change']
# Processed: HAMRO.csv, removed columns: ['Percent Change']
# Processed: NICL.csv, removed columns: ['Percent Change']
# Processed: MBJC.csv, removed columns: ['Percent Change']
# Processed: SICL.csv, removed columns: ['Percent Change']
# Processed: GILB.csv, removed columns: ['Percent Change']
# Processed: HLICF.csv, removed columns: ['Percent Change']
# Processed: HDHPC.csv, removed columns: ['Percent Change']
# Processed: SMJC.csv, removed columns: ['Percent Change']
# Processed: MCHL.csv, removed columns: ['Percent Change']
# Processed: RSML.csv, removed columns: ['Percent Change']
# Processed: BBBLN.csv, removed columns: ['% Change']
# Processed: SANIMA.csv, removed columns: ['Percent Change']
# Processed: ILBS.csv, removed columns: ['Percent Change']
# Processed: RBSL.csv, removed columns: ['% Change']
# Processed: GFCL.csv, removed columns: ['Percent Change']
# Processed: EIC.csv, removed columns: ['Percent Change']
# Processed: CMF2.csv, removed columns: ['Percent Change']
# Processed: PROFL.csv, removed columns: ['Percent Change']
# Processed: AMFI.csv, removed columns: ['Percent Change']
# Processed: DDBL.csv, removed columns: ['Percent Change']
# Processed: SKBBL.csv, removed columns: ['Percent Change']
# Processed: MLBSL.csv, removed columns: ['Percent Change']
# Processed: AVYAN.csv, removed columns: ['Percent Change']
# Processed: KADBL.csv, removed columns: ['Percent Change']
# Processed: SJLIC.csv, removed columns: ['Percent Change']
# Processed: SIGS2.csv, removed columns: ['Percent Change']
# Processed: SAEF.csv, removed columns: ['Percent Change']
# Processed: PRIN.csv, removed columns: ['Percent Change']
# Processed: NSY.csv, removed columns: ['Percent Change']
# Processed: NEFL.csv, removed columns: ['% Change']
# Processed: MSMBS.csv, removed columns: ['Percent Change']
# Processed: DHEL.csv, removed columns: ['Percent Change']
# Processed: UMRH.csv, removed columns: ['Percent Change']
# Processed: SHBL.csv, removed columns: ['Percent Change']
# Processed: MLBBL.csv, removed columns: ['Percent Change']
# Processed: MKCL.csv, removed columns: ['Percent Change']
# Processed: SDBL.csv, removed columns: ['% Change']
# Processed: KNBL.csv, removed columns: ['Percent Change']
# Processed: GLH.csv, removed columns: ['Percent Change']
# Processed: CBBL.csv, removed columns: ['Percent Change']
# Processed: KKHC.csv, removed columns: ['Percent Change']
# Processed: PRVU.csv, removed columns: ['Percent Change']
# Processed: SKHL.csv, removed columns: ['Percent Change']
# Processed: SMPDA.csv, removed columns: ['Percent Change']
# Processed: CFCL.csv, removed columns: ['Percent Change']
# Processed: DOLTI.csv, removed columns: ['Percent Change']
# Processed: NDFL.csv, removed columns: ['% Change']
# Processed: RBBF40.csv, removed columns: ['Percent Change']
# Processed: TNBL.csv, removed columns: ['% Change']
# Processed: RSY.csv, removed columns: ['Percent Change']
# Processed: CBL.csv, removed columns: ['Percent Change']
# Processed: CHCL.csv, removed columns: ['Percent Change']
# Processed: NIBPO.csv, removed columns: ['Percent Change']
# Processed: NRN.csv, removed columns: ['Percent Change']
# Processed: EDBL.csv, removed columns: ['Percent Change']
# Processed: AIC.csv, removed columns: ['% Change']
# Processed: KMFL.csv, removed columns: ['Percent Change']
# Processed: MEN.csv, removed columns: ['Percent Change']
# Processed: NMB.csv, removed columns: ['Percent Change']
# Processed: MABEL.csv, removed columns: ['Percent Change']
# Processed: SLCF.csv, removed columns: ['Percent Change']
# Processed: NMBHF1.csv, removed columns: ['Percent Change']
# Processed: RMF1.csv, removed columns: ['Percent Change']
# Processed: SDESI.csv, removed columns: ['Percent Change']
# Processed: SBI.csv, removed columns: ['Percent Change']
# Processed: KEBL.csv, removed columns: ['% Change']
# Processed: NIBLGF.csv, removed columns: ['Percent Change']
# Processed: JBNL.csv, removed columns: ['% Change']
# Processed: TSHL.csv, removed columns: ['Percent Change']
# Processed: SGIC.csv, removed columns: ['Percent Change']
# Processed: TTL.csv, removed columns: ['Percent Change']
# Processed: MMKJL.csv, removed columns: ['Percent Change']
# Processed: RURU.csv, removed columns: ['Percent Change']
# Processed: MEHL.csv, removed columns: ['Percent Change']
# Processed: MLBS.csv, removed columns: ['Percent Change']
# Processed: NADDF.csv, removed columns: ['Percent Change']
# Processed: LBBL.csv, removed columns: ['Percent Change']
# Processed: EBLD86.csv, removed columns: ['Percent Change']
# Processed: ALBSL.csv, removed columns: ['Percent Change']
# Processed: BUNGAL.csv, removed columns: ['Percent Change']
# Processed: WNLB.csv, removed columns: ['Percent Change']
# Processed: MPFL.csv, removed columns: ['Percent Change']
# Processed: KFL.csv, removed columns: ['% Change']
# Processed: CHDC.csv, removed columns: ['Percent Change']
# Processed: SEWA.csv, removed columns: ['% Change']
# Processed: GHL.csv, removed columns: ['Percent Change']
# Processed: NIL.csv, removed columns: ['Percent Change']
# Processed: BNT.csv, removed columns: ['Percent Change']
# Processed: SAHAS.csv, removed columns: ['Percent Change']
# Processed: SFEF.csv, removed columns: ['Percent Change']
# Processed: NFS.csv, removed columns: ['Percent Change']
# Processed: HIMSTAR.csv, removed columns: ['Percent Change']
# Processed: GMFIL.csv, removed columns: ['Percent Change']
# Processed: CMF1.csv, removed columns: ['Percent Change']
# Processed: DLBS.csv, removed columns: ['Percent Change']
# Processed: GLICL.csv, removed columns: ['Percent Change']
# Processed: GBIMESY2.csv, removed columns: ['Percent Change']
# Processed: EBL.csv, removed columns: ['Percent Change']
# Processed: JLI.csv, removed columns: ['Percent Change']
# Processed: JBBD87.csv, removed columns: ['Percent Change']
# Processed: IHL.csv, removed columns: ['Percent Change']
# Processed: PMLI.csv, removed columns: ['Percent Change']
# Processed: MERO.csv, removed columns: ['Percent Change']
# Processed: KPCL.csv, removed columns: ['Percent Change']
# Processed: HDL.csv, removed columns: ['Percent Change']
# Processed: RBBD83.csv, removed columns: ['Percent Change']
# Processed: NABIL.csv, removed columns: ['Percent Change']
# Processed: NUBL.csv, removed columns: ['Percent Change']
# Processed: NBL.csv, removed columns: ['Percent Change']
# Processed: LUK.csv, removed columns: ['Percent Change']
# Processed: CBLD88.csv, removed columns: ['Percent Change']
# Processed: CITY.csv, removed columns: ['Percent Change']
# Processed: SAPDBL.csv, removed columns: ['Percent Change']
# Processed: RMF2.csv, removed columns: ['Percent Change']
# Processed: SWBBL.csv, removed columns: ['Percent Change']
# Processed: CIVIC.csv, removed columns: ['% Change']
# Processed: PPL.csv, removed columns: ['Percent Change']
# Processed: SONA.csv, removed columns: ['Percent Change']
# Processed: OHL.csv, removed columns: ['Percent Change']
# Processed: GLBSL.csv, removed columns: ['Percent Change']
# Processed: SYPNL.csv, removed columns: ['Percent Change']
# Processed: JSLBB.csv, removed columns: ['Percent Change']
# Processed: HPPL.csv, removed columns: ['Percent Change']
# Processed: NGPL.csv, removed columns: ['Percent Change']
# Processed: RHPL.csv, removed columns: ['Percent Change']
# Processed: EBLD91.csv, removed columns: ['Percent Change']
# Processed: MDB.csv, removed columns: ['Percent Change']
# Processed: SARBTM.csv, removed columns: ['Percent Change']
# Processed: NLICL.csv, removed columns: ['Percent Change']
# Processed: KDBY.csv, removed columns: ['Percent Change']
# Processed: INDB.csv, removed columns: ['% Change']
# Processed: RRHP.csv, removed columns: ['Percent Change']
# Processed: LLBS.csv, removed columns: ['Percent Change']
# Processed: SMBF.csv, removed columns: ['% Change']
# Processed: EBLD85.csv, removed columns: ['Percent Change']
# Processed: UNL.csv, removed columns: ['Percent Change']
# Processed: LVF2.csv, removed columns: ['Percent Change']
# Processed: UPPER.csv, removed columns: ['Percent Change']
# Processed: BNHC.csv, removed columns: ['Percent Change']
# Processed: PBLD84.csv, removed columns: ['Percent Change']
# Processed: HHL.csv, removed columns: ['Percent Change']
# Processed: UFL.csv, removed columns: ['Percent Change']
# Processed: SNLI.csv, removed columns: ['Percent Change']
# Processed: SWMF.csv, removed columns: ['Percent Change']
# Processed: SDLBSL.csv, removed columns: ['Percent Change']
# Processed: CORBL.csv, removed columns: ['Percent Change']
# Processed: AKBSL.csv, removed columns: ['Percent Change']
# Processed: LEMF.csv, removed columns: ['Percent Change']
# Processed: UHEWA.csv, removed columns: ['Percent Change']
# Processed: HIDCLP.csv, removed columns: ['Percent Change']
# Processed: SUBBL.csv, removed columns: ['% Change']
# Processed: MKHL.csv, removed columns: ['Percent Change']
# Processed: SEF.csv, removed columns: ['Percent Change']
# Processed: NIBSF1.csv, removed columns: ['Percent Change']
# Processed: NFCF.csv, removed columns: ['Percent Change']
# Processed: MSBBL.csv, removed columns: ['% Change']
# Processed: TVCL.csv, removed columns: ['Percent Change']
# Processed: METRO.csv, removed columns: ['% Change']
# Processed: SLBSL.csv, removed columns: ['Percent Change']
# Processed: RSDC.csv, removed columns: ['Percent Change']
# Processed: AKJCL.csv, removed columns: ['Percent Change']
# Processed: NIBSF2.csv, removed columns: ['Percent Change']
# Processed: BNL.csv, removed columns: ['Percent Change']
# Processed: SKDBL.csv, removed columns: ['% Change']
# Processed: GBBLPO.csv, removed columns: ['Percent Change']
# Processed: NTC.csv, removed columns: ['Percent Change']
# Processed: SPIL.csv, removed columns: ['Percent Change']
# Processed: NNLB.csv, removed columns: ['Percent Change']
# Processed: BHBL.csv, removed columns: ['Percent Change']
# Processed: NICAD2091.csv, removed columns: ['Percent Change']
# Processed: JEFL.csv, removed columns: ['% Change']
# Processed: GDBL.csv, removed columns: ['% Change']
# Processed: RLEL.csv, removed columns: ['Percent Change']
# Processed: NAGRO.csv, removed columns: ['Percent Change']
# Processed: SAFL.csv, removed columns: ['% Change']
# Processed: JHAPA.csv, removed columns: ['Percent Change']
# Processed: NWCL.csv, removed columns: ['Percent Change']
# Processed: NIB.csv, removed columns: ['Percent Change']
# Processed: MSHL.csv, removed columns: ['Percent Change']
# Processed: GBILD8687.csv, removed columns: ['Percent Change']
# Processed: NIBD84.csv, removed columns: ['Percent Change']
# Processed: MHL.csv, removed columns: ['Percent Change']
# Processed: AKPL.csv, removed columns: ['Percent Change']
# Processed: SSHL.csv, removed columns: ['Percent Change']
# Processed: SABSL.csv, removed columns: ['Percent Change']
# Processed: BHDC.csv, removed columns: ['Percent Change']
# Processed: SPHL.csv, removed columns: ['Percent Change']
# Processed: GIMES1.csv, removed columns: ['Percent Change']
# Processed: UMB.csv, removed columns: ['Percent Change']
# Processed: MNMF1.csv, removed columns: ['Percent Change']
# Processed: HLI.csv, removed columns: ['Percent Change']
# Processed: NMBSBF.csv, removed columns: ['Percent Change']
# Processed: MKLB.csv, removed columns: ['Percent Change']
# Processed: PBD88.csv, removed columns: ['Percent Change']
# Processed: GMLI.csv, removed columns: ['Percent Change']

# %%
import os
import pandas as pd

folder_path = '../data/Stocks/'
consistent_name = 'Close'
columns_to_rename = ['Ltp']  # Variants to standardize

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Rename any variant to the consistent name
        for col in columns_to_rename:
            if col in df.columns:
                df = df.rename(columns={col: consistent_name})
                break  # Avoid multiple renames
        
        # Convert 'Date' to datetime and sort
        df['Date'] = pd.to_datetime(df['Date'])
        df = df.sort_values('Date').reset_index(drop=True)
        
        # Save back
        df.to_csv(file_path, index=False)
        print(f"Standardized columns in: {filename}")
# Out:
# Standardized columns in: ICFCD83.csv
# Standardized columns in: LBBLD89.csv
# Standardized columns in: SPL.csv
# Standardized columns in: BARUN.csv
# Standardized columns in: NYADI.csv
# Standardized columns in: SAGF.csv
# Standardized columns in: SANVI.csv
# Standardized columns in: PSF.csv
# Standardized columns in: NIMBPO.csv
# Standardized columns in: USHL.csv
# Standardized columns in: SMFBS.csv
# Standardized columns in: MIDBL.csv
# Standardized columns in: MBLEF.csv
# Standardized columns in: GIBF1.csv
# Standardized columns in: KDBL.csv
# Standardized columns in: BEDC.csv
# Standardized columns in: CDBL.csv
# Standardized columns in: SFCL.csv
# Standardized columns in: NSLB.csv
# Standardized columns in: GVL.csv
# Standardized columns in: NBBL.csv
# Standardized columns in: NCCB.csv
# Standardized columns in: CHL.csv
# Standardized columns in: UAIL.csv
# Standardized columns in: GBIME.csv
# Standardized columns in: SALICO.csv
# Standardized columns in: RHPC.csv
# Standardized columns in: NICSF.csv
# Standardized columns in: GBBL.csv
# Standardized columns in: MMFDB.csv
# Standardized columns in: LICN.csv
# Standardized columns in: NMBHF2.csv
# Standardized columns in: PPCL.csv
# Standardized columns in: SJCL.csv
# Standardized columns in: NIMB.csv
# Standardized columns in: KSLY.csv
# Standardized columns in: SMHL.csv
# Standardized columns in: NMLBBL.csv
# Standardized columns in: ULBSL.csv
# Standardized columns in: NICA.csv
# Standardized columns in: KBLPO.csv
# Standardized columns in: PFL.csv
# Standardized columns in: ALICL.csv
# Standardized columns in: NICGF.csv
# Standardized columns in: GABL.csv
# Standardized columns in: HATHY.csv
# Standardized columns in: NIDC.csv
# Standardized columns in: RAWA.csv
# Standardized columns in: PCBL.csv
# Standardized columns in: HRL.csv
# Standardized columns in: NABBC.csv
# Standardized columns in: H8020.csv
# Standardized columns in: MATRI.csv
# Standardized columns in: ULI.csv
# Standardized columns in: MSLB.csv
# Standardized columns in: ARDBL.csv
# Standardized columns in: ULHC.csv
# Standardized columns in: NIBLPF.csv
# Standardized columns in: MKJC.csv
# Standardized columns in: SMATA.csv
# Standardized columns in: NICGF2.csv
# Standardized columns in: SBID2090.csv
# Standardized columns in: SPARS.csv
# Standardized columns in: JBBL.csv
# Standardized columns in: RFPL.csv
# Standardized columns in: NMFBS.csv
# Standardized columns in: NIBLSF.csv
# Standardized columns in: AHPC.csv
# Standardized columns in: CKHL.csv
# Standardized columns in: CEFL.csv
# Standardized columns in: NADEP.csv
# Standardized columns in: NIBLSTF.csv
# Standardized columns in: ICFCD88.csv
# Standardized columns in: SMH.csv
# Standardized columns in: SLICL.csv
# Standardized columns in: OMPL.csv
# Standardized columns in: RHGCL.csv
# Standardized columns in: SINDU.csv
# Standardized columns in: KSBBL.csv
# Standardized columns in: SIC.csv
# Standardized columns in: GUFL.csv
# Standardized columns in: GBBD85.csv
# Standardized columns in: BJHL.csv
# Standardized columns in: UFIL.csv
# Standardized columns in: NBF3.csv
# Standardized columns in: FOWAD.csv
# Standardized columns in: MLBL.csv
# Standardized columns in: NBSL.csv
# Standardized columns in: JFL.csv
# Standardized columns in: LBL.csv
# Standardized columns in: BHL.csv
# Standardized columns in: DBBL.csv
# Standardized columns in: LBLD86.csv
# Standardized columns in: DORDI.csv
# Standardized columns in: HBL.csv
# Standardized columns in: CLI.csv
# Standardized columns in: SIGS3.csv
# Standardized columns in: SHLB.csv
# Standardized columns in: SHPC.csv
# Standardized columns in: KRBL.csv
# Standardized columns in: SPC.csv
# Standardized columns in: WOMI.csv
# Standardized columns in: SOHL.csv
# Standardized columns in: TPC.csv
# Standardized columns in: SETI.csv
# Standardized columns in: PRSF.csv
# Standardized columns in: HLBSL.csv
# Standardized columns in: NBF2.csv
# Standardized columns in: NABILP.csv
# Standardized columns in: UPCL.csv
# Standardized columns in: RBCLPO.csv
# Standardized columns in: NLG.csv
# Standardized columns in: ODBL.csv
# Standardized columns in: SAGAR.csv
# Standardized columns in: USLB.csv
# Standardized columns in: GRDBL.csv
# Standardized columns in: JBLB.csv
# Standardized columns in: KBSH.csv
# Standardized columns in: KDL.csv
# Standardized columns in: KSY.csv
# Standardized columns in: LGIL.csv
# Standardized columns in: PHCL.csv
# Standardized columns in: MMF1.csv
# Standardized columns in: RLFL.csv
# Standardized columns in: NICBF.csv
# Standardized columns in: NIFRA.csv
# Standardized columns in: NCDB.csv
# Standardized columns in: JHBL.csv
# Standardized columns in: NRIC.csv
# Standardized columns in: C30MF.csv
# Standardized columns in: MANDU.csv
# Standardized columns in: SIL.csv
# Standardized columns in: SGHC.csv
# Standardized columns in: ADLB.csv
# Standardized columns in: LSL.csv
# Standardized columns in: API.csv
# Standardized columns in: KMCDB.csv
# Standardized columns in: BSBL.csv
# Standardized columns in: RLI.csv
# Standardized columns in: NRM.csv
# Standardized columns in: UNLB.csv
# Standardized columns in: GCIL.csv
# Standardized columns in: NGBL.csv
# Standardized columns in: KSBBLD87.csv
# Standardized columns in: NBBU.csv
# Standardized columns in: MFIL.csv
# Standardized columns in: ICFC.csv
# Standardized columns in: SFFIL.csv
# Standardized columns in: SBID89.csv
# Standardized columns in: CGH.csv
# Standardized columns in: RNLI.csv
# Standardized columns in: SLK.csv
# Standardized columns in: RMDC.csv
# Standardized columns in: BFC.csv
# Standardized columns in: STC.csv
# Standardized columns in: KBL.csv
# Standardized columns in: SHINE.csv
# Standardized columns in: GBLBS.csv
# Standardized columns in: HIDCL.csv
# Standardized columns in: SKHEL.csv
# Standardized columns in: SIFC.csv
# Standardized columns in: PICL.csv
# Standardized columns in: SHIVM.csv
# Standardized columns in: SADBL.csv
# Standardized columns in: SEOS.csv
# Standardized columns in: NICLBSL.csv
# Standardized columns in: RIDI.csv
# Standardized columns in: LEC.csv
# Standardized columns in: MEGA.csv
# Standardized columns in: GMFBS.csv
# Standardized columns in: CREST.csv
# Standardized columns in: NEPSE.csv
# Standardized columns in: MKHC.csv
# Standardized columns in: LVF1.csv
# Standardized columns in: IGI.csv
# Standardized columns in: NHPC.csv
# Standardized columns in: UIC.csv
# Standardized columns in: SRBL.csv
# Standardized columns in: TBBL.csv
# Standardized columns in: NLIC.csv
# Standardized columns in: VLUCL.csv
# Standardized columns in: TRH.csv
# Standardized columns in: SCB.csv
# Standardized columns in: ANLB.csv
# Standardized columns in: HFIN.csv
# Standardized columns in: PLIC.csv
# Standardized columns in: CCBL.csv
# Standardized columns in: SBLD84.csv
# Standardized columns in: MHNL.csv
# Standardized columns in: SMB.csv
# Standardized columns in: UNHPL.csv
# Standardized columns in: NLBBL.csv
# Standardized columns in: SLBS.csv
# Standardized columns in: NMBMF.csv
# Standardized columns in: ALDBL.csv
# Standardized columns in: TMDBL.csv
# Standardized columns in: CIT.csv
# Standardized columns in: SRLI.csv
# Standardized columns in: HATH.csv
# Standardized columns in: HEIP.csv
# Standardized columns in: TAMOR.csv
# Standardized columns in: SHINED.csv
# Standardized columns in: PIC.csv
# Standardized columns in: NEF.csv
# Standardized columns in: KKBL.csv
# Standardized columns in: KBBL.csv
# Standardized columns in: CYCL.csv
# Standardized columns in: SLI.csv
# Standardized columns in: GBILD8485.csv
# Standardized columns in: BPCL.csv
# Standardized columns in: KLBSL.csv
# Standardized columns in: USHEC.csv
# Standardized columns in: PURBL.csv
# Standardized columns in: MNBBL.csv
# Standardized columns in: MHCL.csv
# Standardized columns in: MEL.csv
# Standardized columns in: RBS.csv
# Standardized columns in: ENL.csv
# Standardized columns in: KEF.csv
# Standardized columns in: NICFC.csv
# Standardized columns in: SHEL.csv
# Standardized columns in: SLBBL.csv
# Standardized columns in: BHCL.csv
# Standardized columns in: GSY.csv
# Standardized columns in: GWFD83.csv
# Standardized columns in: BHPL.csv
# Standardized columns in: KMBL.csv
# Standardized columns in: BBC.csv
# Standardized columns in: EHPL.csv
# Standardized columns in: RBCL.csv
# Standardized columns in: JOSHI.csv
# Standardized columns in: ACLBSL.csv
# Standardized columns in: PMHPL.csv
# Standardized columns in: SIKLES.csv
# Standardized columns in: SMFDB.csv
# Standardized columns in: NBB.csv
# Standardized columns in: NSIF2.csv
# Standardized columns in: MAKAR.csv
# Standardized columns in: MBL.csv
# Standardized columns in: BOKL.csv
# Standardized columns in: SPDL.csv
# Standardized columns in: FMDBL.csv
# Standardized columns in: BANDIPUR.csv
# Standardized columns in: HGI.csv
# Standardized columns in: HURJA.csv
# Standardized columns in: DHPL.csv
# Standardized columns in: NHDL.csv
# Standardized columns in: SHL.csv
# Standardized columns in: NMB50.csv
# Standardized columns in: CSY.csv
# Standardized columns in: JALPA.csv
# Standardized columns in: ILI.csv
# Standardized columns in: NMIC.csv
# Standardized columns in: PURE.csv
# Standardized columns in: SBBLJ.csv
# Standardized columns in: VLBS.csv
# Standardized columns in: SABBL.csv
# Standardized columns in: SWASTIK.csv
# Standardized columns in: BGWT.csv
# Standardized columns in: SYFL.csv
# Standardized columns in: SBCF.csv
# Standardized columns in: SFMF.csv
# Standardized columns in: AHL.csv
# Standardized columns in: RADHI.csv
# Standardized columns in: WDBL.csv
# Standardized columns in: NESDO.csv
# Standardized columns in: SBL.csv
# Standardized columns in: SSIS.csv
# Standardized columns in: HEI.csv
# Standardized columns in: MMDBL.csv
# Standardized columns in: UMHL.csv
# Standardized columns in: TDBL.csv
# Standardized columns in: SAIL.csv
# Standardized columns in: NLO.csv
# Standardized columns in: CZBIL.csv
# Standardized columns in: ADBL.csv
# Standardized columns in: HAMRO.csv
# Standardized columns in: NICL.csv
# Standardized columns in: MBJC.csv
# Standardized columns in: SICL.csv
# Standardized columns in: GILB.csv
# Standardized columns in: HLICF.csv
# Standardized columns in: HDHPC.csv
# Standardized columns in: SMJC.csv
# Standardized columns in: MCHL.csv
# Standardized columns in: RSML.csv
# Standardized columns in: BBBLN.csv
# Standardized columns in: SANIMA.csv
# Standardized columns in: ILBS.csv
# Standardized columns in: RBSL.csv
# Standardized columns in: GFCL.csv
# Standardized columns in: EIC.csv
# Standardized columns in: CMF2.csv
# Standardized columns in: PROFL.csv
# Standardized columns in: AMFI.csv
# Standardized columns in: DDBL.csv
# Standardized columns in: SKBBL.csv
# Standardized columns in: MLBSL.csv
# Standardized columns in: AVYAN.csv
# Standardized columns in: KADBL.csv
# Standardized columns in: SJLIC.csv
# Standardized columns in: SIGS2.csv
# Standardized columns in: SAEF.csv
# Standardized columns in: PRIN.csv
# Standardized columns in: NSY.csv
# Standardized columns in: NEFL.csv
# Standardized columns in: MSMBS.csv
# Standardized columns in: DHEL.csv
# Standardized columns in: UMRH.csv
# Standardized columns in: SHBL.csv
# Standardized columns in: MLBBL.csv
# Standardized columns in: MKCL.csv
# Standardized columns in: SDBL.csv
# Standardized columns in: KNBL.csv
# Standardized columns in: GLH.csv
# Standardized columns in: CBBL.csv
# Standardized columns in: KKHC.csv
# Standardized columns in: PRVU.csv
# Standardized columns in: SKHL.csv
# Standardized columns in: SMPDA.csv
# Standardized columns in: CFCL.csv
# Standardized columns in: DOLTI.csv
# Standardized columns in: NDFL.csv
# Standardized columns in: RBBF40.csv
# Standardized columns in: TNBL.csv
# Standardized columns in: RSY.csv
# Standardized columns in: CBL.csv
# Standardized columns in: CHCL.csv
# Standardized columns in: NIBPO.csv
# Standardized columns in: NRN.csv
# Standardized columns in: EDBL.csv
# Standardized columns in: AIC.csv
# Standardized columns in: KMFL.csv
# Standardized columns in: MEN.csv
# Standardized columns in: NMB.csv
# Standardized columns in: MABEL.csv
# Standardized columns in: SLCF.csv
# Standardized columns in: NMBHF1.csv
# Standardized columns in: RMF1.csv
# Standardized columns in: SDESI.csv
# Standardized columns in: SBI.csv
# Standardized columns in: KEBL.csv
# Standardized columns in: NIBLGF.csv
# Standardized columns in: JBNL.csv
# Standardized columns in: TSHL.csv
# Standardized columns in: SGIC.csv
# Standardized columns in: TTL.csv
# Standardized columns in: MMKJL.csv
# Standardized columns in: RURU.csv
# Standardized columns in: MEHL.csv
# Standardized columns in: MLBS.csv
# Standardized columns in: NADDF.csv
# Standardized columns in: LBBL.csv
# Standardized columns in: EBLD86.csv
# Standardized columns in: ALBSL.csv
# Standardized columns in: BUNGAL.csv
# Standardized columns in: WNLB.csv
# Standardized columns in: MPFL.csv
# Standardized columns in: KFL.csv
# Standardized columns in: CHDC.csv
# Standardized columns in: SEWA.csv
# Standardized columns in: GHL.csv
# Standardized columns in: NIL.csv
# Standardized columns in: BNT.csv
# Standardized columns in: SAHAS.csv
# Standardized columns in: SFEF.csv
# Standardized columns in: NFS.csv
# Standardized columns in: HIMSTAR.csv
# Standardized columns in: GMFIL.csv
# Standardized columns in: CMF1.csv
# Standardized columns in: DLBS.csv
# Standardized columns in: GLICL.csv
# Standardized columns in: GBIMESY2.csv
# Standardized columns in: EBL.csv
# Standardized columns in: JLI.csv
# Standardized columns in: JBBD87.csv
# Standardized columns in: IHL.csv
# Standardized columns in: PMLI.csv
# Standardized columns in: MERO.csv
# Standardized columns in: KPCL.csv
# Standardized columns in: HDL.csv
# Standardized columns in: RBBD83.csv
# Standardized columns in: NABIL.csv
# Standardized columns in: NUBL.csv
# Standardized columns in: NBL.csv
# Standardized columns in: LUK.csv
# Standardized columns in: CBLD88.csv
# Standardized columns in: CITY.csv
# Standardized columns in: SAPDBL.csv
# Standardized columns in: RMF2.csv
# Standardized columns in: SWBBL.csv
# Standardized columns in: CIVIC.csv
# Standardized columns in: PPL.csv
# Standardized columns in: SONA.csv
# Standardized columns in: OHL.csv
# Standardized columns in: GLBSL.csv
# Standardized columns in: SYPNL.csv
# Standardized columns in: JSLBB.csv
# Standardized columns in: HPPL.csv
# Standardized columns in: NGPL.csv
# Standardized columns in: RHPL.csv
# Standardized columns in: EBLD91.csv
# Standardized columns in: MDB.csv
# Standardized columns in: SARBTM.csv
# Standardized columns in: NLICL.csv
# Standardized columns in: KDBY.csv
# Standardized columns in: INDB.csv
# Standardized columns in: RRHP.csv
# Standardized columns in: LLBS.csv
# Standardized columns in: SMBF.csv
# Standardized columns in: EBLD85.csv
# Standardized columns in: UNL.csv
# Standardized columns in: LVF2.csv
# Standardized columns in: UPPER.csv
# Standardized columns in: BNHC.csv
# Standardized columns in: PBLD84.csv
# Standardized columns in: HHL.csv
# Standardized columns in: UFL.csv
# Standardized columns in: SNLI.csv
# Standardized columns in: SWMF.csv
# Standardized columns in: SDLBSL.csv
# Standardized columns in: CORBL.csv
# Standardized columns in: AKBSL.csv
# Standardized columns in: LEMF.csv
# Standardized columns in: UHEWA.csv
# Standardized columns in: HIDCLP.csv
# Standardized columns in: SUBBL.csv
# Standardized columns in: MKHL.csv
# Standardized columns in: SEF.csv
# Standardized columns in: NIBSF1.csv
# Standardized columns in: NFCF.csv
# Standardized columns in: MSBBL.csv
# Standardized columns in: TVCL.csv
# Standardized columns in: METRO.csv
# Standardized columns in: SLBSL.csv
# Standardized columns in: RSDC.csv
# Standardized columns in: AKJCL.csv
# Standardized columns in: NIBSF2.csv
# Standardized columns in: BNL.csv
# Standardized columns in: SKDBL.csv
# Standardized columns in: GBBLPO.csv
# Standardized columns in: NTC.csv
# Standardized columns in: SPIL.csv
# Standardized columns in: NNLB.csv
# Standardized columns in: BHBL.csv
# Standardized columns in: NICAD2091.csv
# Standardized columns in: JEFL.csv
# Standardized columns in: GDBL.csv
# Standardized columns in: RLEL.csv
# Standardized columns in: NAGRO.csv
# Standardized columns in: SAFL.csv
# Standardized columns in: JHAPA.csv
# Standardized columns in: NWCL.csv
# Standardized columns in: NIB.csv
# Standardized columns in: MSHL.csv
# Standardized columns in: GBILD8687.csv
# Standardized columns in: NIBD84.csv
# Standardized columns in: MHL.csv
# Standardized columns in: AKPL.csv
# Standardized columns in: SSHL.csv
# Standardized columns in: SABSL.csv
# Standardized columns in: BHDC.csv
# Standardized columns in: SPHL.csv
# Standardized columns in: GIMES1.csv
# Standardized columns in: UMB.csv
# Standardized columns in: MNMF1.csv
# Standardized columns in: HLI.csv
# Standardized columns in: NMBSBF.csv
# Standardized columns in: MKLB.csv
# Standardized columns in: PBD88.csv
# Standardized columns in: GMLI.csv
